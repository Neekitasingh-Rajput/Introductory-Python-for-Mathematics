# %% [markdown]
# Limit:

# %% [markdown]
# Syntax: limit(fn,var,val)

# %%
import sympy as sp
from sympy import *
x = sp.symbols('x')
limit(x**2,x,3)
# Out:
# 9

# %%
n = sp.symbols('n')
limit(1/n,n,oo)
# Out:
# 0

# %% [markdown]
# Q. Find the limit of $x-1/x^2-1$ as x -> 0

# %%
limit((x-1)/(x**2 - 1),x,0)
# Out:
# 1

# %% [markdown]
# Differentiation

# %% [markdown]
# Syntax: diff(fn,w.r.t var, nth derivative)

# %%
diff(x**2 + x, x,1)
# Out:
# 2*x + 1

# %%
diff(x**3 + x**2,x,2)
# Out:
# 2*(3*x + 1)

# %%
diff(log(x),x,1)
# Out:
# 1/x

# %%
y = sp.symbols('y')
diff(log(x+y),x,1)
# Out:
# 1/(x + y)

# %%
diff(sin(x+y),x,1,y,1)
# Out:
# -sin(x + y)

# %% [markdown]
# Q. Find differentiation for the following:- logx - sinx -cosx - $x^3 - e^x$.

# %%
diff(log(x) - sin(x) - cos(x) - x**3 - exp(x),x,1)
# Out:
# -3*x**2 - exp(x) + sin(x) - cos(x) + 1/x

# %%
diff(cos(2*x),x,1)
# Out:
# -2*sin(2*x)

# %% [markdown]
# Integration:

# %% [markdown]
# Syntax: integrate(fn,(var,low lim,upp lim))

# %%
integrate(x**2,(x,0,5))
# Out:
# 125/3

# %% [markdown]
# Q. Find $\int_{0}^{1}  xy dx$

# %%
integrate(x*y, (x,0,1))
# Out:
# y/2

# %% [markdown]
# Q. Find $\int_{0}^{1} \int_{0}^{1}$ $xy$ $dx$ $dy$

# %%
integrate(x*y, (x,0,1),(y,0,1))
# Out:
# 1/4

# %% [markdown]
# Arc Length:

# %% [markdown]
# Arc length is the distance between two points along a section of a curve.
#
# Determining the length of an irregular arc segment is also called rectification of a curve.
#
# The advent of infinitesimal calculus led to general formula that
#
# provides closed-form solutions in some cases.
#
# To compute the length of a curve on the interval [a,b] we compute: $\int_ \sqrt {(1 + (f'(x))^2} dx$

# %% [markdown]
# Q1. Find the arc length of f(x) = $ x^{3/2}$ on [0,2]

# %%
from sympy import *
x = Symbol('x')
integrate(sqrt(1+ (diff(x**(3/2),x,1)**2),(x,0,2)))
# Out:
# 1.0*(x**1.0 + 0.444444444444444)**(3/2)

# %%
f = diff(x**(3/2),x,1)
integrate(sqrt(1+ f**2),(x,0,2))
# Out:
# 3.52552395244872

# %% [markdown]
# Q2. Find the arc length of f(x) = x on [1,2]

# %%
f = diff(x,x,1)
integrate(sqrt(1+ f**2),(x,1,2))
# Out:
# sqrt(2)

# %% [markdown]
# Q3. Find the arc length of f(x) = (1/3)($x^2$ + 2)(3/2) on [0,1].

# %%
f = diff((1/3)*(x**2 +2)*(3/2),x,1)
integrate(sqrt(1+ f**2),(x,0,1))
# Out:
# 1.14779357469632

# %%
z = sp.symbols('z')
integrate(x*y*z, (z,0,x+y), (y,2,x), (x,0,3))
# Out:
# 525/16
